# %%
# imports
import sys
from spotify import spotifyApi

# %%
helper = spotifyApi()
[val for val in list(dir(helper)) if str(val)[0] != '_']
# Out:
# ['client_id',
#  'client_secret',
#  'data_path',
#  'download_spotify_playlist_audio_features',
#  'email',
#  'getClient',
#  'get_followed_users',
#  'get_playlist_audio_features',
#  'get_playlist_content',
#  'get_user_playlists',
#  'name',
#  'rename_spotify_songs',
#  'sp',
#  'test',
#  'username']

# %%
sp = helper.sp
username = helper.username
helper.get_user_playlists(username, sp)
# Out:
# Name: b'Study \xf0\x9f\x93\x9a', Number of songs: 53, Playlist ID: 5c68TrgrsR1COt97GYiHTm
# Name: b'Drank & Drugs', Number of songs: 5, Playlist ID: 5paUN0jPBlwPtOyLi4F7u8
# Name: b'yeye', Number of songs: 12, Playlist ID: 3YUa8BAtVbKmStMYcUnF5z
# Name: b"I'm Just Snacking", Number of songs: 19, Playlist ID: 7f7xecW1muGd5KamjC3EEM
# Name: b'la flame', Number of songs: 394, Playlist ID: 0i3CkxalKp9RRW4jf63PU5
# Name: b'Fashion Killa', Number of songs: 372, Playlist ID: 6k96myNgO28Lt9lZUPqdiU
# Name: b'vamos', Number of songs: 8, Playlist ID: 6pS0A7SrSkuxPSZnsaHd54
# Name: b'View From A Blue Moon', Number of songs: 13, Playlist ID: 0cOa2UTqNsjWO5AJswRZRA
# Name: b'Eargasm', Number of songs: 142, Playlist ID: 088Bt2aW9pdozWiIc1t9j3
# Name: b'Fresh Hits', Number of songs: 51, Playlist ID: 7miiGQXVM6luQXxr1CspvQ
# [{'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/5c68TrgrsR1COt97GYiHTm'},
# ...

# %%
sp.user_follow_users(str(username))
# Out:
# HTTP Error for PUT to https://api.spotify.com/v1/me/following?type=user&ids=1,2,1,7,8,5,2,5,3,1,1 with Params: {} returned 400 due to Client credentials authentication not allowed
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/.pyenv/versions/3.7.4/envs/music/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# ~/.pyenv/versions/3.7.4/envs/music/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     952         if http_error_msg:
# --> 953             raise HTTPError(http_error_msg, response=self)
#     954
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.spotify.com/v1/me/following?type=user&ids=1,2,1,7,8,5,2,5,3,1,1
#
# ...

# %%
sp = helper.sp

# %%
helper.get_user_playlists(helper.username, sp)
# Out:
# Name: b'Study \xf0\x9f\x93\x9a', Number of songs: 53, Playlist ID: 5c68TrgrsR1COt97GYiHTm
# Name: b'Drank & Drugs', Number of songs: 5, Playlist ID: 5paUN0jPBlwPtOyLi4F7u8
# Name: b'yeye', Number of songs: 12, Playlist ID: 3YUa8BAtVbKmStMYcUnF5z
# Name: b"I'm Just Snacking", Number of songs: 19, Playlist ID: 7f7xecW1muGd5KamjC3EEM
# Name: b'la flame', Number of songs: 394, Playlist ID: 0i3CkxalKp9RRW4jf63PU5
# Name: b'Fashion Killa', Number of songs: 372, Playlist ID: 6k96myNgO28Lt9lZUPqdiU
# Name: b'vamos', Number of songs: 8, Playlist ID: 6pS0A7SrSkuxPSZnsaHd54
# Name: b'View From A Blue Moon', Number of songs: 13, Playlist ID: 0cOa2UTqNsjWO5AJswRZRA
# Name: b'Eargasm', Number of songs: 142, Playlist ID: 088Bt2aW9pdozWiIc1t9j3
# Name: b'Fresh Hits', Number of songs: 51, Playlist ID: 7miiGQXVM6luQXxr1CspvQ
# [{'collaborative': False,
#   'description': '',
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/5c68TrgrsR1COt97GYiHTm'},
# ...

# %%
list(dir(sp))
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_append_device_id',
#  '_auth',
#  '_auth_headers',
#  '_auth_manager',
#  '_build_session',
#  '_delete',
#  '_get',
#  '_get_id',
#  '_get_uri',
#  '_internal_call',
#  '_is_uri',
#  '_post',
#  '_put',
#  '_search_multiple_markets',
#  '_session',
#  'add_to_queue',
#  'album',
#  'album_tracks',
#  'albums',
#  'artist',
#  'artist_albums',
#  'artist_related_artists',
#  'artist_top_tracks',
#  'artists',
#  'audio_analysis',
#  'audio_features',
#  'auth_manager',
#  'available_markets',
#  'backoff_factor',
#  'categories',
#  'category',
# ...

# %%
list(dir(sp.current_user_following_users([str(helper.username)])))
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/me/following/contains with Params: {'ids': '12178525311', 'type': 'user'} returned 400 due to Client credentials authentication not allowed
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/.pyenv/versions/3.7.4/envs/music/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# ~/.pyenv/versions/3.7.4/envs/music/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     952         if http_error_msg:
# --> 953             raise HTTPError(http_error_msg, response=self)
#     954
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.spotify.com/v1/me/following/contains?ids=12178525311&type=user
#
# ...
